# %%
import glob
import pandas as pd

# %% [markdown]
# # Baby Names by State

# %%
dirpath = "./namesbystate/"
csv_files = glob.glob(dirpath + "/*.TXT")

df_list = []
for f in csv_files:
    df_list.append(pd.read_csv(f, header=None, 
                               names=["state", "gender", "year", "name", "occurrences"]))

# %%
big_df = pd.concat(df_list, ignore_index=True, axis=0)
len(big_df)
# Out:
# 6408041

# %%
big_df.head(10)
# Out:
#   state gender  year      name  occurrences
# 0    ID      F  1910      Mary           53
# 1    ID      F  1910   Dorothy           31
# 2    ID      F  1910     Helen           30
# 3    ID      F  1910  Margaret           24
# 4    ID      F  1910      Ruth           24
# 5    ID      F  1910    Gladys           20
# 6    ID      F  1910     Alice           19
# 7    ID      F  1910   Mildred           19
# 8    ID      F  1910    Thelma           19
# 9    ID      F  1910     Edith           17

# %%
big_df.to_csv("./output/namesbystate_combined.csv")

# %%
# TODO: assign rankings?

# %%
subset_df = big_df.groupby(["year", "state", "gender"]).apply(
    lambda x: x.sort_values(by="occurrences", ascending=False).head(1)).copy()

# %%
subset_df.to_csv("./output/subset_df.csv")

# %%
subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11526 entries, (1910, 'AK', 'F', 2838142) to (2022, 'WY', 'M', 4598904)
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        11526 non-null  object
#  1   gender       11526 non-null  object
#  2   year         11526 non-null  int64
#  3   name         11526 non-null  object
#  4   occurrences  11526 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 862.3+ KB

# %% [markdown]
# # Exploring popularity of "-den" names

# %%
big_df[(big_df["name"].str.endswith("den")) | \
       (big_df["name"].str.endswith("dan")) | \
       (big_df["name"].str.endswith("dyn")) \
      ].sort_values(by="occurrences", ascending=False).head(20)
# Out:
#         state gender  year    name  occurrences
# 3292085    CA      M  2012  Jayden         2871
# 3289196    CA      M  2011  Jayden         2754
# 3295001    CA      M  2013  Jayden         2581
# 3286287    CA      M  2010  Jayden         2444
# 3297902    CA      M  2014  Jayden         2383
# 3283365    CA      M  2009  Jayden         2263
# 3300842    CA      M  2015  Jayden         2134
# 3280458    CA      M  2008  Jayden         2055
# 3292096    CA      M  2012   Aiden         2003
# 3286298    CA      M  2010   Aiden         1941
# 3289209    CA      M  2011   Aiden         1913
# 3300847    CA      M  2015   Aiden         1907
# 2426493    TX      M  2013  Jayden         1902
# 2421306    TX      M  2011  Jayden         1886
# 3297909    CA      M  2014   Aiden         1883
# 2423879    TX      M  2012  Jayden         1882
# 3303783    CA      M  2016  Jayden         1861
# 2418729    TX      M  2010  Jayden         1820
# 3283372    CA      M  2009   Aiden         1804
# 3280465    CA      M  2008   Aiden         1793

# %% [markdown]
# # All Baby Names by Year and Gender

# %%
import re

dirpath = "./names/"
csv_files = glob.glob(dirpath + "/*.txt")

regex_str = re.compile(f"yob(\d\d\d\d).txt")

df_list = []
for f in csv_files:
    year = re.search(regex_str, f).groups()[0]
    temp_df = pd.read_csv(
        f, header=None, 
        names=["name", "gender", "occurrences"])
    temp_df.insert(1, "year", year)
    df_list.append(temp_df)

print(df_list)
# Out:
# [          name  year gender  occurrences
# 0        Emily  2000      F        25957
# 1       Hannah  2000      F        23085
# 2      Madison  2000      F        19968
# 3       Ashley  2000      F        17998
# 4        Sarah  2000      F        17712
# ...        ...   ...    ...          ...
# 29771     Zeph  2000      M            5
# 29772    Zeven  2000      M            5
# 29773    Ziggy  2000      M            5
# 29774       Zo  2000      M            5
# 29775    Zyier  2000      M            5
#
# [29776 rows x 4 columns],            name  year gender  occurrences
# 0          Emma  2014      F        20958
# 1        Olivia  2014      F        19829
# 2        Sophia  2014      F        18636
# 3      Isabella  2014      F        17125
# 4           Ava  2014      F        15721
# ...         ...   ...    ...          ...
# 33289    Zykeem  2014      M            5
# 33290    Zymeer  2014      M            5
# 33291   Zymiere  2014      M            5
# 33292     Zyran  2014      M            5
# 33293     Zyrin  2014      M            5
#
# [33294 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1938      F        56216
# 1      Barbara  1938      F        39276
# 2     Patricia  1938      F        27557
# 3        Betty  1938      F        25506
# 4      Shirley  1938      F        23767
# ...        ...   ...    ...          ...
# 9026      Zach  1938      M            5
# 9027    Zannie  1938      M            5
# 9028  Zeferino  1938      M            5
# 9029   Zelbert  1938      M            5
# 9030     Zenon  1938      M            5
#
# [9031 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1910      F        22848
# 1        Helen  1910      F        10479
# 2     Margaret  1910      F         8226
# 3      Dorothy  1910      F         7318
# 4         Ruth  1910      F         7212
# ...        ...   ...    ...          ...
# 4624   Woodson  1910      M            5
# 4625     Woody  1910      M            5
# 4626     Wyman  1910      M            5
# 4627    Yoshio  1910      M            5
# 4628    Zennie  1910      M            5
#
# [4629 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1904      F        14961
# 1        Helen  1904      F         6488
# 2         Anna  1904      F         5330
# 3     Margaret  1904      F         5302
# 4         Ruth  1904      F         4900
# ...        ...   ...    ...          ...
# 3555   Willian  1904      M            5
# 3556    Woodie  1904      M            5
# 3557     Woody  1904      M            5
# 3558    Worley  1904      M            5
# 3559       Yee  1904      M            5
#
# [3560 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1905      F        16067
# 1        Helen  1905      F         6811
# 2     Margaret  1905      F         5690
# 3         Anna  1905      F         5424
# 4         Ruth  1905      F         5068
# ...        ...   ...    ...          ...
# 3650   Wilburt  1905      M            5
# 3651   Wilfrid  1905      M            5
# 3652   Willian  1905      M            5
# 3653  Winifred  1905      M            5
# 3654   Woodson  1905      M            5
#
# [3655 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1911      F        24390
# 1        Helen  1911      F        11801
# 2     Margaret  1911      F         9279
# 3      Dorothy  1911      F         8869
# 4         Ruth  1911      F         8003
# ...        ...   ...    ...          ...
# 4862  Woodford  1911      M            5
# 4863     Woody  1911      M            5
# 4864    Yoshio  1911      M            5
# 4865     Zenas  1911      M            5
# 4866     Zenon  1911      M            5
#
# [4867 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1939      F        54902
# 1       Barbara  1939      F        37258
# 2      Patricia  1939      F        29706
# 3         Betty  1939      F        23645
# 4       Shirley  1939      F        20448
# ...         ...   ...    ...          ...
# 8913     Yoshio  1939      M            5
# 8914      Yukio  1939      M            5
# 8915  Zachariah  1939      M            5
# 8916      Zelma  1939      M            5
# 8917      Zenon  1939      M            5
#
# [8918 rows x 4 columns],            name  year gender  occurrences
# 0          Emma  2015      F        20478
# 1        Olivia  2015      F        19717
# 2        Sophia  2015      F        17445
# 3           Ava  2015      F        16399
# 4      Isabella  2015      F        15646
# ...         ...   ...    ...          ...
# 33165    Zykell  2015      M            5
# 33166    Zyking  2015      M            5
# 33167     Zykir  2015      M            5
# 33168     Zyrus  2015      M            5
# 33169      Zyus  2015      M            5
#
# [33170 rows x 4 columns],           name  year gender  occurrences
# 0        Emily  2001      F        25059
# 1      Madison  2001      F        22166
# 2       Hannah  2001      F        20720
# 3       Ashley  2001      F        16531
# 4       Alexis  2001      F        16403
# ...        ...   ...    ...          ...
# 30276     Zyad  2001      M            5
# 30277    Zyere  2001      M            5
# 30278    Zykel  2001      M            5
# 30279    Zyrek  2001      M            5
# 30280  Zyshaun  2001      M            5
#
# [30281 rows x 4 columns],            name  year gender  occurrences
# 0          Emma  2017      F        19857
# 1        Olivia  2017      F        18763
# 2           Ava  2017      F        16005
# 3      Isabella  2017      F        15231
# 4        Sophia  2017      F        14925
# ...         ...   ...    ...          ...
# 32665     Zykir  2017      M            5
# 32666     Zylin  2017      M            5
# 32667     Zylis  2017      M            5
# 32668     Zylyn  2017      M            5
# 32669     Zyrie  2017      M            5
#
# [32670 rows x 4 columns],           name  year gender  occurrences
# 0        Emily  2003      F        25691
# 1         Emma  2003      F        22714
# 2      Madison  2003      F        20201
# 3       Hannah  2003      F        17638
# 4       Olivia  2003      F        16152
# ...        ...   ...    ...          ...
# 31189   Zorion  2003      M            5
# 31190  Zxavian  2003      M            5
# 31191     Zyad  2003      M            5
# 31192   Zykeem  2003      M            5
# 31193   Zysean  2003      M            5
#
# [31194 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1907      F        17580
# 1        Helen  1907      F         7579
# 2     Margaret  1907      F         6713
# 3         Anna  1907      F         5575
# 4         Ruth  1907      F         5573
# ...        ...   ...    ...          ...
# 3943      Wray  1907      M            5
# 3944     Wyman  1907      M            5
# 3945       Zeb  1907      M            5
# 3946      Zeke  1907      M            5
# 3947      Zeno  1907      M            5
#
# [3948 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1913      F        36642
# 1        Helen  1913      F        18888
# 2      Dorothy  1913      F        14674
# 3     Margaret  1913      F        14486
# 4         Ruth  1913      F        12609
# ...        ...   ...    ...          ...
# 6963    Yutaka  1913      M            5
# 6964      Zach  1913      M            5
# 6965    Zeddie  1913      M            5
# 6966     Zenas  1913      M            5
# 6967     Zenus  1913      M            5
#
# [6968 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1898      F        14406
# 1         Anna  1898      F         5773
# 2        Helen  1898      F         5230
# 3     Margaret  1898      F         4696
# 4         Ruth  1898      F         4249
# ...        ...   ...    ...          ...
# 3259     Wince  1898      M            5
# 3260   Winford  1898      M            5
# 3261      Wing  1898      M            5
# 3262     Wyman  1898      M            5
# 3263       Zed  1898      M            5
#
# [3264 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1899      F        13172
# 1         Anna  1899      F         5115
# 2        Helen  1899      F         5048
# 3     Margaret  1899      F         4249
# 4         Ruth  1899      F         3912
# ...        ...   ...    ...          ...
# 3037    Waddie  1899      M            5
# 3038   Wilhelm  1899      M            5
# 3039   Winford  1899      M            5
# 3040    Winton  1899      M            5
# 3041     Young  1899      M            5
#
# [3042 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1912      F        32304
# 1        Helen  1912      F        16133
# 2      Dorothy  1912      F        12645
# 3     Margaret  1912      F        12536
# 4         Ruth  1912      F        11280
# ...        ...   ...    ...          ...
# 6345     Woods  1912      M            5
# 6346      Wray  1912      M            5
# 6347      Wynn  1912      M            5
# 6348      York  1912      M            5
# 6349    Yutaka  1912      M            5
#
# [6350 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1906      F        16370
# 1        Helen  1906      F         7176
# 2     Margaret  1906      F         6096
# 3         Anna  1906      F         5502
# 4         Ruth  1906      F         5140
# ...        ...   ...    ...          ...
# 3628  Winifred  1906      M            5
# 3629   Winslow  1906      M            5
# 3630      Wray  1906      M            5
# 3631     Wyman  1906      M            5
# 3632    Zeddie  1906      M            5
#
# [3633 rows x 4 columns],           name  year gender  occurrences
# 0        Emily  2002      F        24468
# 1      Madison  2002      F        21773
# 2       Hannah  2002      F        18827
# 3         Emma  2002      F        16554
# 4       Alexis  2002      F        15636
# ...        ...   ...    ...          ...
# 30567    Zimri  2002      M            5
# 30568    Zoran  2002      M            5
# 30569     Zyen  2002      M            5
# 30570    Zylan  2002      M            5
# 30571    Zyonn  2002      M            5
#
# [30572 rows x 4 columns],            name  year gender  occurrences
# 0          Emma  2016      F        19536
# 1        Olivia  2016      F        19397
# 2           Ava  2016      F        16338
# 3        Sophia  2016      F        16171
# 4      Isabella  2016      F        14846
# ...         ...   ...    ...          ...
# 33054    Zolton  2016      M            5
# 33055    Zurich  2016      M            5
# 33056    Zyahir  2016      M            5
# 33057      Zyel  2016      M            5
# 33058     Zylyn  2016      M            5
#
# [33059 rows x 4 columns],             name  year gender  occurrences
# 0         Sophia  2012      F        22325
# 1           Emma  2012      F        20964
# 2       Isabella  2012      F        19126
# 3         Olivia  2012      F        17328
# 4            Ava  2012      F        15545
# ...          ...   ...    ...          ...
# 33766      Zylin  2012      M            5
# 33767     Zymari  2012      M            5
# 33768      Zyrin  2012      M            5
# 33769      Zyrus  2012      M            5
# 33770  Zytaevius  2012      M            5
#
# [33771 rows x 4 columns],              name  year gender  occurrences
# 0           Emily  2006      F        21410
# 1            Emma  2006      F        19126
# 2         Madison  2006      F        18632
# 3        Isabella  2006      F        18228
# 4             Ava  2006      F        16943
# ...           ...   ...    ...          ...
# 34097      Zymire  2006      M            5
# 34098  Zyquavious  2006      M            5
# 34099      Zyrell  2006      M            5
# 34100     Zyshaun  2006      M            5
# 34101     Zyshawn  2006      M            5
#
# [34102 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1902      F        14486
# 1        Helen  1902      F         5967
# 2         Anna  1902      F         5288
# 3     Margaret  1902      F         5011
# 4         Ruth  1902      F         4384
# ...        ...   ...    ...          ...
# 3357   Woodrow  1902      M            5
# 3358    Wright  1902      M            5
# 3359     Wyman  1902      M            5
# 3360     Yancy  1902      M            5
# 3361    Zollie  1902      M            5
#
# [3362 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1916      F        61438
# 1        Helen  1916      F        32661
# 2      Dorothy  1916      F        27418
# 3     Margaret  1916      F        24953
# 4         Ruth  1916      F        23189
# ...        ...   ...    ...          ...
# 9691     Zelma  1916      M            5
# 9692      Zera  1916      M            5
# 9693    Zettie  1916      M            5
# 9694      Ziba  1916      M            5
# 9695      Zina  1916      M            5
#
# [9696 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1889      F        11648
# 1          Anna  1889      F         5062
# 2     Elizabeth  1889      F         3058
# 3      Margaret  1889      F         2917
# 4          Emma  1889      F         2884
# ...         ...   ...    ...          ...
# 2585     Weldon  1889      M            5
# 2586    Wendell  1889      M            5
# 2587    Wilhelm  1889      M            5
# 2588       Zeke  1889      M            5
# 2589      Zenas  1889      M            5
#
# [2590 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1888      F        11754
# 1          Anna  1888      F         4982
# 2     Elizabeth  1888      F         3224
# 3          Emma  1888      F         3087
# 4      Margaret  1888      F         2904
# ...         ...   ...    ...          ...
# 2646     Vaughn  1888      M            5
# 2647     Vernie  1888      M            5
# 2648       Watt  1888      M            5
# 2649    Winston  1888      M            5
# 2650      Zelma  1888      M            5
#
# [2651 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1917      F        64280
# 1         Helen  1917      F        34251
# 2       Dorothy  1917      F        28852
# 3      Margaret  1917      F        25560
# 4          Ruth  1917      F        23568
# ...         ...   ...    ...          ...
# 9907  Yoshiharu  1917      M            5
# 9908    Zebulon  1917      M            5
# 9909     Zeddie  1917      M            5
# 9910       Zeke  1917      M            5
# 9911       Zola  1917      M            5
#
# [9912 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1903      F        14275
# 1        Helen  1903      F         6129
# 2         Anna  1903      F         5098
# 3     Margaret  1903      F         5046
# 4         Ruth  1903      F         4517
# ...        ...   ...    ...          ...
# 3384      Webb  1903      M            5
# 3385   Wilburt  1903      M            5
# 3386    Worthy  1903      M            5
# 3387     Young  1903      M            5
# 3388    Zollie  1903      M            5
#
# [3389 rows x 4 columns],              name  year gender  occurrences
# 0           Emily  2007      F        19359
# 1        Isabella  2007      F        19140
# 2            Emma  2007      F        18381
# 3             Ava  2007      F        18053
# 4         Madison  2007      F        17965
# ...           ...   ...    ...          ...
# 34961       Zylin  2007      M            5
# 34962       Zyonn  2007      M            5
# 34963   Zyquarius  2007      M            5
# 34964  Zyquavious  2007      M            5
# 34965      Zyrese  2007      M            5
#
# [34966 rows x 4 columns],            name  year gender  occurrences
# 0        Sophia  2013      F        21244
# 1          Emma  2013      F        20958
# 2        Olivia  2013      F        18446
# 3      Isabella  2013      F        17663
# 4           Ava  2013      F        15265
# ...         ...   ...    ...          ...
# 33324     Zyere  2013      M            5
# 33325     Zylar  2013      M            5
# 33326    Zymari  2013      M            5
# 33327    Zymeer  2013      M            5
# 33328     Zyree  2013      M            5
#
# [33329 rows x 4 columns],             name  year gender  occurrences
# 0          Emily  2005      F        23949
# 1           Emma  2005      F        20353
# 2        Madison  2005      F        19577
# 3        Abigail  2005      F        15755
# 4         Olivia  2005      F        15699
# ...          ...   ...    ...          ...
# 32554    Zymiere  2005      M            5
# 32555     Zyrell  2005      M            5
# 32556     Zyrian  2005      M            5
# 32557     Zyshon  2005      M            5
# 32558  Zytavious  2005      M            5
#
# [32559 rows x 4 columns],            name  year gender  occurrences
# 0        Sophia  2011      F        21856
# 1      Isabella  2011      F        19927
# 2          Emma  2011      F        18814
# 3        Olivia  2011      F        17331
# 4           Ava  2011      F        15512
# ...         ...   ...    ...          ...
# 33929     Zylar  2011      M            5
# 33930     Zylas  2011      M            5
# 33931     Zyran  2011      M            5
# 33932   Zyshawn  2011      M            5
# 33933  Zytavion  2011      M            5
#
# [33934 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1915      F        58187
# 1         Helen  1915      F        30866
# 2       Dorothy  1915      F        25154
# 3      Margaret  1915      F        23054
# 4          Ruth  1915      F        21878
# ...         ...   ...    ...          ...
# 9352     Yewell  1915      M            5
# 9353  Zachariah  1915      M            5
# 9354      Zelma  1915      M            5
# 9355       Zora  1915      M            5
# 9356    Zygmont  1915      M            5
#
# [9357 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1901      F        13136
# 1        Helen  1901      F         5247
# 2         Anna  1901      F         4923
# 3     Margaret  1901      F         4424
# 4         Ruth  1901      F         3974
# ...        ...   ...    ...          ...
# 3148     Welby  1901      M            5
# 3149   Westley  1901      M            5
# 3150  Williard  1901      M            5
# 3151     Young  1901      M            5
# 3152       Zeb  1901      M            5
#
# [3153 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1929      F        63512
# 1        Betty  1929      F        36674
# 2      Dorothy  1929      F        31476
# 3        Helen  1929      F        20982
# 4     Margaret  1929      F        19209
# ...        ...   ...    ...          ...
# 9817   Yoshimi  1929      M            5
# 9818   Yoshiro  1929      M            5
# 9819  Zeferino  1929      M            5
# 9820      Zell  1929      M            5
# 9821   Zygmund  1929      M            5
#
# [9822 rows x 4 columns],             name  year gender  occurrences
# 0           Mary  1928      F        66870
# 1          Betty  1928      F        36082
# 2        Dorothy  1928      F        33734
# 3          Helen  1928      F        22936
# 4       Margaret  1928      F        20296
# ...          ...   ...    ...          ...
# 10156      Wynne  1928      M            5
# 10157     Yvonne  1928      M            5
# 10158  Zachariah  1928      M            5
# 10159     Zebbie  1928      M            5
# 10160     Zolton  1928      M            5
#
# [10161 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1900      F        16705
# 1        Helen  1900      F         6342
# 2         Anna  1900      F         6114
# 3     Margaret  1900      F         5304
# 4         Ruth  1900      F         4765
# ...        ...   ...    ...          ...
# 3724     White  1900      M            5
# 3725   Wilhelm  1900      M            5
# 3726  Winifred  1900      M            5
# 3727    Woodie  1900      M            5
# 3728      Zeno  1900      M            5
#
# [3729 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1914      F        45346
# 1        Helen  1914      F        23221
# 2      Dorothy  1914      F        18782
# 3     Margaret  1914      F        17763
# 4         Ruth  1914      F        15839
# ...        ...   ...    ...          ...
# 7960    Wister  1914      M            5
# 7961   Wofford  1914      M            5
# 7962     Yasuo  1914      M            5
# 7963      Zell  1914      M            5
# 7964    Zenith  1914      M            5
#
# [7965 rows x 4 columns],             name  year gender  occurrences
# 0       Isabella  2010      F        22929
# 1         Sophia  2010      F        20652
# 2           Emma  2010      F        17357
# 3         Olivia  2010      F        17033
# 4            Ava  2010      F        15438
# ...          ...   ...    ...          ...
# 34093    Zymaire  2010      M            5
# 34094     Zyonne  2010      M            5
# 34095  Zyquarius  2010      M            5
# 34096      Zyran  2010      M            5
# 34097      Zzyzx  2010      M            5
#
# [34098 rows x 4 columns],            name  year gender  occurrences
# 0         Emily  2004      F        25040
# 1          Emma  2004      F        21617
# 2       Madison  2004      F        20628
# 3        Olivia  2004      F        16107
# 4        Hannah  2004      F        15610
# ...         ...   ...    ...          ...
# 32053     Zykee  2004      M            5
# 32054  Zymarion  2004      M            5
# 32055    Zymeir  2004      M            5
# 32056    Zyrell  2004      M            5
# 32057     Zyron  2004      M            5
#
# [32058 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1973      F        62446
# 1           Amy  1973      F        26964
# 2      Michelle  1973      F        26934
# 3      Kimberly  1973      F        23532
# 4          Lisa  1973      F        22673
# ...         ...   ...    ...          ...
# 15679       Zan  1973      M            5
# 15680   Zerrick  1973      M            5
# 15681      Zeus  1973      M            5
# 15682      Zion  1973      M            5
# 15683      Zuri  1973      M            5
#
# [15684 rows x 4 columns],            name  year gender  occurrences
# 0          Lisa  1967      F        52436
# 1      Kimberly  1967      F        33098
# 2      Michelle  1967      F        30826
# 3          Mary  1967      F        25320
# 4         Susan  1967      F        22263
# ...         ...   ...    ...          ...
# 12399  Zbigniew  1967      M            5
# 12400   Zebedee  1967      M            5
# 12401      Zeno  1967      M            5
# 12402     Zenon  1967      M            5
# 12403       Zev  1967      M            5
#
# [12404 rows x 4 columns],            name  year gender  occurrences
# 0         Emily  1998      F        26185
# 1        Hannah  1998      F        21375
# 2      Samantha  1998      F        20194
# 3         Sarah  1998      F        19894
# 4        Ashley  1998      F        19873
# ...         ...   ...    ...          ...
# 27904    Zayvon  1998      M            5
# 27905    Ziaire  1998      M            5
# 27906  Zildjian  1998      M            5
# 27907    Zykeem  1998      M            5
# 27908    Zyquan  1998      M            5
#
# [27909 rows x 4 columns],            name  year gender  occurrences
# 0         Emily  1999      F        26539
# 1        Hannah  1999      F        21678
# 2        Alexis  1999      F        19235
# 3         Sarah  1999      F        19115
# 4      Samantha  1999      F        19041
# ...         ...   ...    ...          ...
# 28552     Zyier  1999      M            5
# 28553    Zyquan  1999      M            5
# 28554    Zyquez  1999      M            5
# 28555     Zyron  1999      M            5
# 28556   Zyshaun  1999      M            5
#
# [28557 rows x 4 columns],            name  year gender  occurrences
# 0          Lisa  1966      F        56918
# 1      Kimberly  1966      F        32230
# 2          Mary  1966      F        28886
# 3      Michelle  1966      F        27157
# 4         Karen  1966      F        25449
# ...         ...   ...    ...          ...
# 12155   Yarnell  1966      M            5
# 12156   Yolanda  1966      M            5
# 12157      Yvon  1966      M            5
# 12158    Zalman  1966      M            5
# 12159   Zygmunt  1966      M            5
#
# [12160 rows x 4 columns],             name  year gender  occurrences
# 0       Jennifer  1972      F        63602
# 1       Michelle  1972      F        29287
# 2           Lisa  1972      F        27547
# 3       Kimberly  1972      F        26284
# 4            Amy  1972      F        25873
# ...          ...   ...    ...          ...
# 15411     Yvonne  1972      M            5
# 15412   Zacarias  1972      M            5
# 15413  Zacharian  1972      M            5
# 15414        Zed  1972      M            5
# 15415  Zimbalist  1972      M            5
#
# [15416 rows x 4 columns],             name  year gender  occurrences
# 0           Mary  1958      F        55846
# 1          Susan  1958      F        45169
# 2          Linda  1958      F        41901
# 3          Karen  1958      F        38474
# 4       Patricia  1958      F        37954
# ...          ...   ...    ...          ...
# 11526       Wren  1958      M            5
# 11527        Wyn  1958      M            5
# 11528     Ysabel  1958      M            5
# 11529  Zachariah  1958      M            5
# 11530     Zettie  1958      M            5
#
# [11531 rows x 4 columns],            name  year gender  occurrences
# 0          Lisa  1964      F        54270
# 1          Mary  1964      F        40982
# 2         Susan  1964      F        31514
# 3         Karen  1964      F        30251
# 4      Patricia  1964      F        26086
# ...         ...   ...    ...          ...
# 12392       Zac  1964      M            5
# 12393    Zalman  1964      M            5
# 12394    Zedric  1964      M            5
# 12395      Zeno  1964      M            5
# 12396      Zina  1964      M            5
#
# [12397 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1970      F        46153
# 1          Lisa  1970      F        38964
# 2      Kimberly  1970      F        34136
# 3      Michelle  1970      F        34047
# 4           Amy  1970      F        25211
# ...         ...   ...    ...          ...
# 14778      Zaid  1970      M            5
# 14779    Zalmen  1970      M            5
# 14780    Zavier  1970      M            5
# 14781   Zebulon  1970      M            5
# 14782       Zon  1970      M            5
#
# [14783 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1971      F        56775
# 1      Michelle  1971      F        33159
# 2          Lisa  1971      F        32912
# 3      Kimberly  1971      F        30702
# 4           Amy  1971      F        26237
# ...         ...   ...    ...          ...
# 15296    Zawdie  1971      M            5
# 15297       Zel  1971      M            5
# 15298      Zeno  1971      M            5
# 15299     Zenon  1971      M            5
# 15300   Zigmond  1971      M            5
#
# [15301 rows x 4 columns],            name  year gender  occurrences
# 0          Lisa  1965      F        60267
# 1          Mary  1965      F        34271
# 2         Karen  1965      F        32868
# 3      Kimberly  1965      F        28836
# 4         Susan  1965      F        26327
# ...         ...   ...    ...          ...
# 11951    Willem  1965      M            5
# 11952   Winferd  1965      M            5
# 11953    Worley  1965      M            5
# 11954    Worthy  1965      M            5
# 11955  Wwilliam  1965      M            5
#
# [11956 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1959      F        54492
# 1        Susan  1959      F        41609
# 2        Linda  1959      F        40409
# 3        Karen  1959      F        36774
# 4        Donna  1959      F        36463
# ...        ...   ...    ...          ...
# 11762   Ysabel  1959      M            5
# 11763   Zalman  1959      M            5
# 11764   Zebbie  1959      M            5
# 11765  Zebulon  1959      M            5
# 11766  Zyndall  1959      M            5
#
# [11767 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1961      F        47677
# 1         Lisa  1961      F        42711
# 2        Susan  1961      F        37530
# 3        Linda  1961      F        35580
# 4        Karen  1961      F        34693
# ...        ...   ...    ...          ...
# 12177   Yehuda  1961      M            5
# 12178     Yogi  1961      M            5
# 12179     Yvan  1961      M            5
# 12180   Zannie  1961      M            5
# 12181  Zendell  1961      M            5
#
# [12182 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1975      F        58188
# 1           Amy  1975      F        32254
# 2       Heather  1975      F        24302
# 3       Melissa  1975      F        24169
# 4        Angela  1975      F        23361
# ...         ...   ...    ...          ...
# 16946  Zederick  1975      M            5
# 16947    Zedric  1975      M            5
# 16948     Zenas  1975      M            5
# 16949    Zollie  1975      M            5
# 16950     Zoran  1975      M            5
#
# [16951 rows x 4 columns],            name  year gender  occurrences
# 0         Linda  1949      F        91017
# 1          Mary  1949      F        66870
# 2      Patricia  1949      F        46328
# 3       Barbara  1949      F        42599
# 4         Susan  1949      F        37709
# ...         ...   ...    ...          ...
# 10266   Ygnacio  1949      M            5
# 10267     Yusuf  1949      M            5
# 10268      Yves  1949      M            5
# 10269    Zannie  1949      M            5
# 10270  Zeferino  1949      M            5
#
# [10271 rows x 4 columns],            name  year gender  occurrences
# 0         Linda  1948      F        96215
# 1          Mary  1948      F        68600
# 2       Barbara  1948      F        46826
# 3      Patricia  1948      F        46140
# 4         Susan  1948      F        35988
# ...         ...   ...    ...          ...
# 10235     Yancy  1948      M            5
# 10236   Zachery  1948      M            5
# 10237   Zebulon  1948      M            5
# 10238       Zed  1948      M            5
# 10239      Zell  1948      M            5
#
# [10240 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1974      F        63110
# 1           Amy  1974      F        29564
# 2      Michelle  1974      F        25830
# 3       Heather  1974      F        23181
# 4        Angela  1974      F        22804
# ...         ...   ...    ...          ...
# 16246      Yero  1974      M            5
# 16247     Yonah  1974      M            5
# 16248   Yonatan  1974      M            5
# 16249    Yousef  1974      M            5
# 16250     Zenas  1974      M            5
#
# [16251 rows x 4 columns],          name  year gender  occurrences
# 0        Mary  1960      F        51481
# 1       Susan  1960      F        39205
# 2       Linda  1960      F        37317
# 3       Karen  1960      F        36382
# 4       Donna  1960      F        34139
# ...       ...   ...    ...          ...
# 11922   Yates  1960      M            5
# 11923  Ysabel  1960      M            5
# 11924   Yusuf  1960      M            5
# 11925  Zalmen  1960      M            5
# 11926  Zandel  1960      M            5
#
# [11927 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1976      F        59474
# 1           Amy  1976      F        31338
# 2       Melissa  1976      F        25095
# 3       Heather  1976      F        24191
# 4        Angela  1976      F        22038
# ...         ...   ...    ...          ...
# 17398  Zacharie  1976      M            5
# 17399   Zebulun  1976      M            5
# 17400    Zedric  1976      M            5
# 17401       Zee  1976      M            5
# 17402     Zenas  1976      M            5
#
# [17403 rows x 4 columns],             name  year gender  occurrences
# 0           Lisa  1962      F        46073
# 1           Mary  1962      F        43495
# 2          Susan  1962      F        35740
# 3          Karen  1962      F        35186
# 4          Linda  1962      F        31467
# ...          ...   ...    ...          ...
# 12211       Yvan  1962      M            5
# 12212        Zac  1962      M            5
# 12213   Zacarias  1962      M            5
# 12214  Zachariah  1962      M            5
# 12215     Zollie  1962      M            5
#
# [12216 rows x 4 columns],            name  year gender  occurrences
# 0       Jessica  1989      F        47889
# 1        Ashley  1989      F        47586
# 2      Brittany  1989      F        37792
# 3        Amanda  1989      F        36834
# 4         Sarah  1989      F        27792
# ...         ...   ...    ...          ...
# 23772   Zebulin  1989      M            5
# 23773       Zek  1989      M            5
# 23774       Zen  1989      M            5
# 23775      Zeno  1989      M            5
# 23776     Zerek  1989      M            5
#
# [23777 rows x 4 columns],            name  year gender  occurrences
# 0       Jessica  1988      F        51552
# 1        Ashley  1988      F        49972
# 2        Amanda  1988      F        39458
# 3         Sarah  1988      F        28372
# 4      Jennifer  1988      F        27891
# ...         ...   ...    ...          ...
# 22368     Ziggy  1988      M            5
# 22369    Zishan  1988      M            5
# 22370       Zoe  1988      M            5
# 22371      Zong  1988      M            5
# 22372     Zubin  1988      M            5
#
# [22373 rows x 4 columns],             name  year gender  occurrences
# 0           Lisa  1963      F        56035
# 1           Mary  1963      F        41550
# 2          Susan  1963      F        33995
# 3          Karen  1963      F        32486
# 4          Linda  1963      F        27723
# ...          ...   ...    ...          ...
# 12278        Wyn  1963      M            5
# 12279     Yaakov  1963      M            5
# 12280        Zac  1963      M            5
# 12281  Zachariah  1963      M            5
# 12282       Zora  1963      M            5
#
# [12283 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1977      F        58964
# 1       Melissa  1977      F        26880
# 2           Amy  1977      F        26731
# 3       Jessica  1977      F        24845
# 4       Heather  1977      F        23775
# ...         ...   ...    ...          ...
# 18183     Ziyad  1977      M            5
# 18184       Zoe  1977      M            5
# 18185    Zollie  1977      M            5
# 18186      Zuri  1977      M            5
# 18187    Zuriel  1977      M            5
#
# [18188 rows x 4 columns],            name  year gender  occurrences
# 0         Linda  1952      F        67080
# 1          Mary  1952      F        65627
# 2      Patricia  1952      F        53090
# 3       Deborah  1952      F        49810
# 4         Susan  1952      F        41346
# ...         ...   ...    ...          ...
# 10641   Woodroe  1952      M            5
# 10642    Wydell  1952      M            5
# 10643      Zach  1952      M            5
# 10644    Zebbie  1952      M            5
# 10645      Zeke  1952      M            5
#
# [10646 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1946      F        67470
# 1        Linda  1946      F        52710
# 2     Patricia  1946      F        46299
# 3      Barbara  1946      F        45123
# 4        Carol  1946      F        34283
# ...        ...   ...    ...          ...
# 9700      Yvon  1946      M            5
# 9701    Yvonne  1946      M            5
# 9702    Zebbie  1946      M            5
# 9703   Zebulon  1946      M            5
# 9704  Zeferino  1946      M            5
#
# [9705 rows x 4 columns],            name  year gender  occurrences
# 0        Ashley  1991      F        43480
# 1       Jessica  1991      F        43397
# 2      Brittany  1991      F        29090
# 3        Amanda  1991      F        28895
# 4      Samantha  1991      F        25647
# ...         ...   ...    ...          ...
# 25108      Zeev  1991      M            5
# 25109      Zein  1991      M            5
# 25110    Zerick  1991      M            5
# 25111    Zeshan  1991      M            5
# 25112    Zuhair  1991      M            5
#
# [25113 rows x 4 columns],            name  year gender  occurrences
# 0       Jessica  1985      F        48346
# 1        Ashley  1985      F        47008
# 2      Jennifer  1985      F        42657
# 3        Amanda  1985      F        39056
# 4         Sarah  1985      F        24880
# ...         ...   ...    ...          ...
# 20087      Zeus  1985      M            5
# 20088       Zia  1985      M            5
# 20089       Ziv  1985      M            5
# 20090     Ziyad  1985      M            5
# 20091    Zubair  1985      M            5
#
# [20092 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1984      F        50561
# 1       Jessica  1984      F        45857
# 2        Ashley  1984      F        38776
# 3        Amanda  1984      F        33915
# 4         Sarah  1984      F        25888
# ...         ...   ...    ...          ...
# 19510      Zayd  1984      M            5
# 19511   Zebedee  1984      M            5
# 19512   Zebulan  1984      M            5
# 19513      Zeno  1984      M            5
# 19514    Zeshan  1984      M            5
#
# [19515 rows x 4 columns],            name  year gender  occurrences
# 0       Jessica  1990      F        46478
# 1        Ashley  1990      F        45561
# 2      Brittany  1990      F        36536
# 3        Amanda  1990      F        34413
# 4      Samantha  1990      F        25868
# ...         ...   ...    ...          ...
# 24714      Zeus  1990      M            5
# 24715     Ziyad  1990      M            5
# 24716     Zoilo  1990      M            5
# 24717     Zoran  1990      M            5
# 24718       Zvi  1990      M            5
#
# [24719 rows x 4 columns],            name  year gender  occurrences
# 0         Linda  1947      F        99693
# 1          Mary  1947      F        71685
# 2      Patricia  1947      F        51278
# 3       Barbara  1947      F        48798
# 4        Sandra  1947      F        34779
# ...         ...   ...    ...          ...
# 10366  Zacarias  1947      M            5
# 10367       Zan  1947      M            5
# 10368    Zannie  1947      M            5
# 10369    Zebbie  1947      M            5
# 10370      Zell  1947      M            5
#
# [10371 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1953      F        64388
# 1         Linda  1953      F        61281
# 2       Deborah  1953      F        52196
# 3      Patricia  1953      F        51021
# 4         Susan  1953      F        44295
# ...         ...   ...    ...          ...
# 10831  Wwilliam  1953      M            5
# 10832   Wwlliam  1953      M            5
# 10833     Yakov  1953      M            5
# 10834      Yves  1953      M            5
# 10835    Zackie  1953      M            5
#
# [10836 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1979      F        56718
# 1       Melissa  1979      F        34051
# 2        Amanda  1979      F        31927
# 3       Jessica  1979      F        27782
# 4           Amy  1979      F        21612
# ...         ...   ...    ...          ...
# 19038       Zan  1979      M            5
# 19039       Zed  1979      M            5
# 19040   Zeeshan  1979      M            5
# 19041   Zerrick  1979      M            5
# 19042       Zon  1979      M            5
#
# [19043 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1945      F        59280
# 1         Linda  1945      F        41462
# 2       Barbara  1945      F        38274
# 3      Patricia  1945      F        35841
# 4         Carol  1945      F        30387
# ...         ...   ...    ...          ...
# 9019     Ysmael  1945      M            5
# 9020   Zacarias  1945      M            5
# 9021       Zach  1945      M            5
# 9022  Zachariah  1945      M            5
# 9023      Zenon  1945      M            5
#
# [9024 rows x 4 columns],            name  year gender  occurrences
# 0         Linda  1951      F        73981
# 1          Mary  1951      F        65723
# 2      Patricia  1951      F        56446
# 3       Deborah  1951      F        42055
# 4       Barbara  1951      F        40619
# ...         ...   ...    ...          ...
# 10462   Woodley  1951      M            5
# 10463    Worthy  1951      M            5
# 10464    Yancey  1951      M            5
# 10465   Yisroel  1951      M            5
# 10466   Zackery  1951      M            5
#
# [10467 rows x 4 columns],            name  year gender  occurrences
# 0       Jessica  1986      F        52682
# 1        Ashley  1986      F        49672
# 2        Amanda  1986      F        40532
# 3      Jennifer  1986      F        36185
# 4         Sarah  1986      F        28161
# ...         ...   ...    ...          ...
# 20658       Zia  1986      M            5
# 20659       Zoe  1986      M            5
# 20660     Zoilo  1986      M            5
# 20661    Zollie  1986      M            5
# 20662    Zubair  1986      M            5
#
# [20663 rows x 4 columns],            name  year gender  occurrences
# 0        Ashley  1992      F        38458
# 1       Jessica  1992      F        38360
# 2        Amanda  1992      F        25037
# 3      Brittany  1992      F        24982
# 4         Sarah  1992      F        24636
# ...         ...   ...    ...          ...
# 25427     Ziyad  1992      M            5
# 25428    Zohrab  1992      M            5
# 25429     Zubin  1992      M            5
# 25430    Zuhair  1992      M            5
# 25431     Zyair  1992      M            5
#
# [25432 rows x 4 columns],            name  year gender  occurrences
# 0       Jessica  1993      F        34990
# 1        Ashley  1993      F        34850
# 2         Sarah  1993      F        24254
# 3      Samantha  1993      F        23668
# 4         Emily  1993      F        23592
# ...         ...   ...    ...          ...
# 25963     Ziare  1993      M            5
# 25964    Zishan  1993      M            5
# 25965     Zoheb  1993      M            5
# 25966      Zuri  1993      M            5
# 25967       Zvi  1993      M            5
#
# [25968 rows x 4 columns],            name  year gender  occurrences
# 0       Jessica  1987      F        55996
# 1        Ashley  1987      F        54853
# 2        Amanda  1987      F        41788
# 3      Jennifer  1987      F        32705
# 4         Sarah  1987      F        27894
# ...         ...   ...    ...          ...
# 21408     Zakry  1987      M            5
# 21409    Zander  1987      M            5
# 21410   Zebulen  1987      M            5
# 21411      Zeus  1987      M            5
# 21412     Zubin  1987      M            5
#
# [21413 rows x 4 columns],            name  year gender  occurrences
# 0         Linda  1950      F        80431
# 1          Mary  1950      F        65481
# 2      Patricia  1950      F        47944
# 3       Barbara  1950      F        41554
# 4         Susan  1950      F        38016
# ...         ...   ...    ...          ...
# 10300   Zachery  1950      M            5
# 10301   Zackary  1950      M            5
# 10302    Zannie  1950      M            5
# 10303      Zeke  1950      M            5
# 10304   Zygmunt  1950      M            5
#
# [10305 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1944      F        62470
# 1      Barbara  1944      F        39195
# 2        Linda  1944      F        38413
# 3     Patricia  1944      F        36875
# 4        Carol  1944      F        30456
# ...        ...   ...    ...          ...
# 9147     Yancy  1944      M            5
# 9148    Zackie  1944      M            5
# 9149    Zennie  1944      M            5
# 9150      Zeno  1944      M            5
# 9151   Zigmund  1944      M            5
#
# [9152 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1978      F        56323
# 1       Melissa  1978      F        28328
# 2       Jessica  1978      F        26103
# 3           Amy  1978      F        23212
# 4       Heather  1978      F        22270
# ...         ...   ...    ...          ...
# 18232       Zan  1978      M            5
# 18233    Zerick  1978      M            5
# 18234    Zikomo  1978      M            5
# 18235    Zollie  1978      M            5
# 18236       Zon  1978      M            5
#
# [18237 rows x 4 columns],              name  year gender  occurrences
# 0            Mary  1940      F        56213
# 1         Barbara  1940      F        36735
# 2        Patricia  1940      F        32665
# 3          Judith  1940      F        22384
# 4           Betty  1940      F        22075
# ...           ...   ...    ...          ...
# 8957  Worthington  1940      M            5
# 8958        Wynne  1940      M            5
# 8959       Ysabel  1940      M            5
# 8960       Zackie  1940      M            5
# 8961        Zenas  1940      M            5
#
# [8962 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1954      F        68022
# 1         Linda  1954      F        55373
# 2       Deborah  1954      F        54682
# 3      Patricia  1954      F        49148
# 4         Susan  1954      F        47162
# ...         ...   ...    ...          ...
# 10979   Yehudah  1954      M            5
# 10980  Yitzchok  1954      M            5
# 10981    Zalman  1954      M            5
# 10982    Zannie  1954      M            5
# 10983    Zeddie  1954      M            5
#
# [10984 rows x 4 columns],            name  year gender  occurrences
# 0          Lisa  1968      F        49537
# 1      Michelle  1968      F        33222
# 2      Kimberly  1968      F        31908
# 3      Jennifer  1968      F        26850
# 4       Melissa  1968      F        21727
# ...         ...   ...    ...          ...
# 12937     Wynne  1968      M            5
# 12938      Zain  1968      M            5
# 12939    Zalman  1968      M            5
# 12940    Zavier  1968      M            5
# 12941   Zedrick  1968      M            5
#
# [12942 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1983      F        54350
# 1       Jessica  1983      F        45281
# 2        Amanda  1983      F        33754
# 3        Ashley  1983      F        33293
# 4         Sarah  1983      F        27231
# ...         ...   ...    ...          ...
# 19408  Zebediah  1983      M            5
# 19409   Zebulan  1983      M            5
# 19410       Zef  1983      M            5
# 19411     Zenas  1983      M            5
# 19412     Zoran  1983      M            5
#
# [19413 rows x 4 columns],           name  year gender  occurrences
# 0        Emily  1997      F        25735
# 1      Jessica  1997      F        21045
# 2       Ashley  1997      F        20895
# 3        Sarah  1997      F        20714
# 4       Hannah  1997      F        20594
# ...        ...   ...    ...          ...
# 26968    Zhane  1997      M            5
# 26969     Zian  1997      M            5
# 26970     Ziar  1997      M            5
# 26971   Zohair  1997      M            5
# 26972    Zohar  1997      M            5
#
# [26973 rows x 4 columns],            name  year gender  occurrences
# 0         Emily  1996      F        25151
# 1       Jessica  1996      F        24201
# 2        Ashley  1996      F        23679
# 3         Sarah  1996      F        21041
# 4      Samantha  1996      F        20552
# ...         ...   ...    ...          ...
# 26421       Zhi  1996      M            5
# 26422  Zildjian  1996      M            5
# 26423     Zishe  1996      M            5
# 26424     Zoran  1996      M            5
# 26425     Zyler  1996      M            5
#
# [26426 rows x 4 columns],            name  year gender  occurrences
# 0      Jennifer  1982      F        57119
# 1       Jessica  1982      F        45453
# 2        Amanda  1982      F        34213
# 3         Sarah  1982      F        28488
# 4       Melissa  1982      F        25867
# ...         ...   ...    ...          ...
# 19695      Zaki  1982      M            5
# 19696   Zebulin  1982      M            5
# 19697  Zedekiah  1982      M            5
# 19698     Zubin  1982      M            5
# 19699    Zuriel  1982      M            5
#
# [19700 rows x 4 columns],            name  year gender  occurrences
# 0          Lisa  1969      F        45025
# 1      Michelle  1969      F        34318
# 2      Jennifer  1969      F        33702
# 3      Kimberly  1969      F        33081
# 4       Melissa  1969      F        23022
# ...         ...   ...    ...          ...
# 13745    Zalmen  1969      M            5
# 13746   Zedrick  1969      M            5
# 13747       Zen  1969      M            5
# 13748     Zenas  1969      M            5
# 13749    Zolton  1969      M            5
#
# [13750 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1955      F        63173
# 1       Deborah  1955      F        52316
# 2         Linda  1955      F        51300
# 3         Debra  1955      F        50559
# 4         Susan  1955      F        47418
# ...         ...   ...    ...          ...
# 11125    Zannie  1955      M            5
# 11126   Zedrick  1955      M            5
# ...
# 31514     Zymari  2020      M            5
# 31515        Zyn  2020      M            5
# 31516      Zyran  2020      M            5
#
# [31517 rows x 4 columns],             name  year gender  occurrences
# 0           Emma  2008      F        18823
# 1       Isabella  2008      F        18625
# 2          Emily  2008      F        17441
# 3         Olivia  2008      F        17086
# 4            Ava  2008      F        17047
# ...          ...   ...    ...          ...
# 35089     Zymire  2008      M            5
# 35090  Zyquarius  2008      M            5
# 35091  Zyquavion  2008      M            5
# 35092     Zyrell  2008      M            5
# 35093      Zyren  2008      M            5
#
# [35094 rows x 4 columns],             name  year gender  occurrences
# 0         Olivia  2022      F        16573
# 1           Emma  2022      F        14435
# 2      Charlotte  2022      F        12891
# 3         Amelia  2022      F        12333
# 4         Sophia  2022      F        12310
# ...          ...   ...    ...          ...
# 31910     Zuberi  2022      M            5
# 31911       Zydn  2022      M            5
# 31912      Zylon  2022      M            5
# 31913     Zymeer  2022      M            5
# 31914    Zymeire  2022      M            5
#
# [31915 rows x 4 columns],             name  year gender  occurrences
# 0           Mary  1926      F        67833
# 1        Dorothy  1926      F        36616
# 2          Betty  1926      F        32964
# 3          Helen  1926      F        26886
# 4       Margaret  1926      F        23074
# ...          ...   ...    ...          ...
# 10454       Yves  1926      M            5
# 10455  Zachariah  1926      M            5
# 10456        Zan  1926      M            5
# 10457   Zeferino  1926      M            5
# 10458     Zelmer  1926      M            5
#
# [10459 rows x 4 columns],          name  year gender  occurrences
# 0        Mary  1932      F        59879
# 1       Betty  1932      F        34419
# 2     Barbara  1932      F        26318
# 3     Dorothy  1932      F        24975
# 4        Joan  1932      F        21044
# ...       ...   ...    ...          ...
# 9377     Yves  1932      M            5
# 9378   Yvonne  1932      M            5
# 9379      Zed  1932      M            5
# 9380    Zelda  1932      M            5
# 9381    Zenas  1932      M            5
#
# [9382 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1891      F        11703
# 1          Anna  1891      F         5099
# 2      Margaret  1891      F         3065
# 3     Elizabeth  1891      F         3059
# 4          Emma  1891      F         2884
# ...         ...   ...    ...          ...
# 2655    Willian  1891      M            5
# 2656    Winford  1891      M            5
# 2657    Winston  1891      M            5
# 2658      Wyatt  1891      M            5
# 2659      Wylie  1891      M            5
#
# [2660 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1885      F         9128
# 1          Anna  1885      F         3994
# 2          Emma  1885      F         2728
# 3     Elizabeth  1885      F         2582
# 4      Margaret  1885      F         2204
# ...         ...   ...    ...          ...
# 2289     Wallie  1885      M            5
# 2290    Willian  1885      M            5
# 2291       Wirt  1885      M            5
# 2292        Yee  1885      M            5
# 2293        Zeb  1885      M            5
#
# [2294 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1884      F         9217
# 1          Anna  1884      F         3860
# 2          Emma  1884      F         2587
# 3     Elizabeth  1884      F         2549
# 4        Minnie  1884      F         2243
# ...         ...   ...    ...          ...
# 2292   Williard  1884      M            5
# 2293      Willy  1884      M            5
# 2294    Winston  1884      M            5
# 2295       York  1884      M            5
# 2296  Zachariah  1884      M            5
#
# [2297 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1890      F        12078
# 1          Anna  1890      F         5233
# 2     Elizabeth  1890      F         3112
# 3      Margaret  1890      F         3100
# 4          Emma  1890      F         2980
# ...         ...   ...    ...          ...
# 2690  Whitfield  1890      M            5
# 2691    Wilhelm  1890      M            5
# 2692    Woodfin  1890      M            5
# 2693     Woodie  1890      M            5
# 2694    Woodson  1890      M            5
#
# [2695 rows x 4 columns],          name  year gender  occurrences
# 0        Mary  1933      F        55518
# 1       Betty  1933      F        31528
# 2     Barbara  1933      F        26949
# 3     Dorothy  1933      F        22050
# 4        Joan  1933      F        19292
# ...       ...   ...    ...          ...
# 9009     Zach  1933      M            5
# 9010      Zan  1933      M            5
# 9011   Zannie  1933      M            5
# 9012   Zebbie  1933      M            5
# 9013     Zeke  1933      M            5
#
# [9014 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1927      F        70641
# 1       Dorothy  1927      F        35994
# 2         Betty  1927      F        35425
# 3         Helen  1927      F        25319
# 4      Margaret  1927      F        21964
# ...         ...   ...    ...          ...
# 10399     Zaven  1927      M            5
# 10400  Zeferino  1927      M            5
# 10401    Zeldon  1927      M            5
# 10402     Zenis  1927      M            5
# 10403   Zygmund  1927      M            5
#
# [10404 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1923      F        71635
# 1       Dorothy  1923      F        39043
# 2         Helen  1923      F        31486
# 3      Margaret  1923      F        26135
# 4         Betty  1923      F        25990
# ...         ...   ...    ...          ...
# 10638    Zeddie  1923      M            5
# 10639      Zeke  1923      M            5
# 10640      Zell  1923      M            5
# 10641      Zola  1923      M            5
# 10642    Zolton  1923      M            5
#
# [10643 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1937      F        55643
# 1      Barbara  1937      F        34916
# 2     Patricia  1937      F        26838
# 3      Shirley  1937      F        26823
# 4        Betty  1937      F        25331
# ...        ...   ...    ...          ...
# 8943     Wyley  1937      M            5
# 8944      Ynes  1937      M            5
# 8945   Yoshito  1937      M            5
# 8946  Zacarias  1937      M            5
# 8947     Zelma  1937      M            5
#
# [8948 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1894      F        13151
# 1          Anna  1894      F         5565
# 2      Margaret  1894      F         3700
# 3         Helen  1894      F         3676
# 4     Elizabeth  1894      F         3425
# ...         ...   ...    ...          ...
# 2936      Worth  1894      M            5
# 2937     Xavier  1894      M            5
# 2938     Yancey  1894      M            5
# 2939      Yancy  1894      M            5
# 2940      Young  1894      M            5
#
# [2941 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1880      F         7065
# 1          Anna  1880      F         2604
# 2          Emma  1880      F         2003
# 3     Elizabeth  1880      F         1939
# 4        Minnie  1880      F         1746
# ...         ...   ...    ...          ...
# 1995     Woodie  1880      M            5
# 1996     Worthy  1880      M            5
# 1997     Wright  1880      M            5
# 1998       York  1880      M            5
# 1999  Zachariah  1880      M            5
#
# [2000 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1881      F         6919
# 1          Anna  1881      F         2698
# 2          Emma  1881      F         2034
# 3     Elizabeth  1881      F         1852
# 4      Margaret  1881      F         1658
# ...         ...   ...    ...          ...
# 1929     Wiliam  1881      M            5
# 1930     Wilton  1881      M            5
# 1931       Wing  1881      M            5
# 1932       Wood  1881      M            5
# 1933     Wright  1881      M            5
#
# [1934 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1895      F        13447
# 1          Anna  1895      F         5950
# 2         Helen  1895      F         4023
# 3      Margaret  1895      F         3931
# 4     Elizabeth  1895      F         3603
# ...         ...   ...    ...          ...
# 3044       Whit  1895      M            5
# 3045    Wilfrid  1895      M            5
# 3046    Wilhelm  1895      M            5
# 3047       Wong  1895      M            5
# 3048        Yee  1895      M            5
#
# [3049 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1936      F        54374
# 1      Shirley  1936      F        35160
# 2      Barbara  1936      F        31680
# 3        Betty  1936      F        25869
# 4     Patricia  1936      F        23917
# ...        ...   ...    ...          ...
# 8888   Willies  1936      M            5
# 8889    Wilman  1936      M            5
# 8890    Wister  1936      M            5
# 8891    Worthy  1936      M            5
# 8892     Wyley  1936      M            5
#
# [8893 rows x 4 columns],             name  year gender  occurrences
# 0           Mary  1922      F        72176
# 1        Dorothy  1922      F        37715
# 2          Helen  1922      F        32510
# 3       Margaret  1922      F        26862
# 4           Ruth  1922      F        23632
# ...          ...   ...    ...          ...
# 10751  Yoshiyuki  1922      M            5
# 10752      Zenas  1922      M            5
# 10753     Zenith  1922      M            5
# 10754       Zola  1922      M            5
# 10755     Zolton  1922      M            5
#
# [10756 rows x 4 columns],            name  year gender  occurrences
# 0          Emma  2018      F        18801
# 1        Olivia  2018      F        18039
# 2           Ava  2018      F        15010
# 3      Isabella  2018      F        14548
# 4        Sophia  2018      F        13991
# ...         ...   ...    ...          ...
# 32216     Zylas  2018      M            5
# 32217     Zyran  2018      M            5
# 32218     Zyrie  2018      M            5
# 32219     Zyron  2018      M            5
# 32220     Zzyzx  2018      M            5
#
# [32221 rows x 4 columns],          name  year gender  occurrences
# 0        Mary  1934      F        56933
# 1       Betty  1934      F        31088
# 2     Barbara  1934      F        29236
# 3     Shirley  1934      F        22843
# 4     Dorothy  1934      F        21284
# ...       ...   ...    ...          ...
# 9174      Zan  1934      M            5
# 9175   Zeddie  1934      M            5
# 9176    Zenon  1934      M            5
# 9177  Zigmund  1934      M            5
# 9178  Zygmunt  1934      M            5
#
# [9179 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1920      F        70983
# 1       Dorothy  1920      F        36643
# 2         Helen  1920      F        35097
# 3      Margaret  1920      F        27994
# 4          Ruth  1920      F        26102
# ...         ...   ...    ...          ...
# 10751     Zearl  1920      M            5
# 10752  Zeferino  1920      M            5
# 10753      Zeke  1920      M            5
# 10754      Zera  1920      M            5
# 10755   Zygmont  1920      M            5
#
# [10756 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1908      F        18665
# 1        Helen  1908      F         8439
# 2     Margaret  1908      F         6976
# 3         Ruth  1908      F         6180
# 4         Anna  1908      F         5860
# ...        ...   ...    ...          ...
# 4013   Wilhelm  1908      M            5
# 4014     Wilma  1908      M            5
# 4015    Worthy  1908      M            5
# 4016    Yancey  1908      M            5
# 4017      Zeno  1908      M            5
#
# [4018 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1883      F         8012
# 1          Anna  1883      F         3306
# 2          Emma  1883      F         2367
# 3     Elizabeth  1883      F         2255
# 4        Minnie  1883      F         2035
# ...         ...   ...    ...          ...
# 2079      Titus  1883      M            5
# 2080      Toney  1883      M            5
# 2081      Verna  1883      M            5
# 2082     Winnie  1883      M            5
# 2083   Winthrop  1883      M            5
#
# [2084 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1897      F        13413
# 1         Anna  1897      F         5429
# 2        Helen  1897      F         4519
# 3     Margaret  1897      F         4146
# 4         Ruth  1897      F         3878
# ...        ...   ...    ...          ...
# 3023    Woodie  1897      M            5
# 3024     Woody  1897      M            5
# 3025    Worley  1897      M            5
# 3026     Worth  1897      M            5
# 3027    Xavier  1897      M            5
#
# [3028 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1896      F        13811
# 1         Anna  1896      F         5860
# 2        Helen  1896      F         4392
# 3     Margaret  1896      F         4050
# 4         Ruth  1896      F         3905
# ...        ...   ...    ...          ...
# 3086    Worley  1896      M            5
# 3087    Wright  1896      M            5
# 3088    Xavier  1896      M            5
# 3089      York  1896      M            5
# 3090    Zollie  1896      M            5
#
# [3091 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1882      F         8148
# 1          Anna  1882      F         3143
# 2          Emma  1882      F         2303
# 3     Elizabeth  1882      F         2186
# 4        Minnie  1882      F         2004
# ...         ...   ...    ...          ...
# 2122       Wirt  1882      M            5
# 2123    Woodson  1882      M            5
# 2124      Woody  1882      M            5
# 2125     Worley  1882      M            5
# 2126        Zed  1882      M            5
#
# [2127 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1909      F        19259
# 1        Helen  1909      F         9250
# 2     Margaret  1909      F         7358
# 3         Ruth  1909      F         6509
# 4      Dorothy  1909      F         6253
# ...        ...   ...    ...          ...
# 4222   Wilfrid  1909      M            5
# 4223     Wilma  1909      M            5
# 4224  Winthrop  1909      M            5
# 4225    Winton  1909      M            5
# 4226   Zygmund  1909      M            5
#
# [4227 rows x 4 columns],            name  year gender  occurrences
# 0          Mary  1921      F        73984
# 1       Dorothy  1921      F        39087
# 2         Helen  1921      F        34822
# 3      Margaret  1921      F        28468
# 4          Ruth  1921      F        25783
# ...         ...   ...    ...          ...
# 10850   Zackary  1921      M            5
# 10851    Zebdee  1921      M            5
# 10852      Zell  1921      M            5
# 10853   Zigmont  1921      M            5
# 10854   Zygmont  1921      M            5
#
# [10855 rows x 4 columns],           name  year gender  occurrences
# 0         Mary  1935      F        55073
# 1      Shirley  1935      F        42359
# 2      Barbara  1935      F        30699
# 3        Betty  1935      F        28676
# 4     Patricia  1935      F        22876
# ...        ...   ...    ...          ...
# 9032   Winfrey  1935      M            5
# 9033     Yancy  1935      M            5
# 9034    Yazzie  1935      M            5
# 9035  Zaragoza  1935      M            5
# 9036     Zenas  1935      M            5
#
# [9037 rows x 4 columns],            name  year gender  occurrences
# 0        Olivia  2019      F        18549
# 1          Emma  2019      F        17194
# 2           Ava  2019      F        14528
# 3        Sophia  2019      F        13787
# 4      Isabella  2019      F        13376
# ...         ...   ...    ...          ...
# 32104    Zyheem  2019      M            5
# 32105     Zykel  2019      M            5
# 32106    Zyking  2019      M            5
# 32107       Zyn  2019      M            5
# 32108     Zyran  2019      M            5
#
# [32109 rows x 4 columns]]

# %%
big_df = pd.concat(df_list, ignore_index=True, axis=0)

# %% [markdown]
# # Assessing Most Popular and Most Unique Baby Names

# %%
highest_df = big_df.groupby(["year", "gender"]).apply(
    lambda x: x[x["occurrences"] == x["occurrences"].max()]).copy()

# %%
", ".join(sorted(highest_df["name"].unique()))
# Out:
# 'Ashley, David, Emily, Emma, Isabella, Jacob, James, Jennifer, Jessica, John, Liam, Linda, Lisa, Mary, Michael, Noah, Olivia, Robert, Sophia'

# %%
highest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 286 entries, ('1880', 'F', 1935794) to ('2022', 'M', 1849802)
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         286 non-null    object
#  1   year         286 non-null    object
#  2   gender       286 non-null    object
#  3   occurrences  286 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 26.1+ KB

# %%
highest_df.to_csv("./output/most_popular_names_1880_2022.csv")

# %% [markdown]
# ## Flourish connected scatter plot
# <a href='https://public.flourish.studio/visualisation/14251422/'>Most Popular Baby Names</a>

# %%
lowest_df = big_df.groupby(["year", "gender"]).apply(
    lambda x: x[x["occurrences"] == x["occurrences"].min()]).copy()

# %%
lowest_df_counts_df = lowest_df["name"].value_counts().reset_index(name='Counts')

# %%
lowest_df_counts_df.to_csv("./output/least_popular_names_1880_2022.csv")

# %% [markdown]
# ## Flourish table
# <a href='https://public.flourish.studio/visualisation/14251690/'>Most Unique Baby Names</a>
